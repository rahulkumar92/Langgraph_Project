# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI
#from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
from dotenv import load_dotenv
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI
import sqlite3
import requests

# %%
load_dotenv()
llm=ChatOpenAI(proxy_model_name='gpt-4o')
# Out:
# C:\Users\I533555\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3641: UserWarning: WARNING! proxy_model_name is not default parameter.
#                 proxy_model_name was transferred to model_kwargs.
#                 Please confirm that proxy_model_name is what you intended.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 load_dotenv()
# ----> 2 llm=ChatOpenAI(proxy_model_name='gpt-4o')
#
# File c:\Users\I533555\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\I533555\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_openai\chat_models\base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
#    1084         "http_client": self.http_async_client
#    1085         or _get_default_async_httpx_client(
#    (...)   1088         "api_key": async_api_key_value,
#    1089     }
# -> 1090     self.root_async_client = openai.AsyncOpenAI(
#    1091         **client_params,
#    1092         **async_specific,  # type: ignore[arg-type]
#    1093     )
#    1094     self.async_client = self.root_async_client.chat.completions
#    1095 return self
#
# File c:\Users\I533555\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
